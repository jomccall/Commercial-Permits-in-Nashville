# %%
import requests
import matplotlib.pyplot as plt
from IPython.display import Image
import folium
import pickle
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import pyproj

# %matplotlib inline

#conda install -c conda-forge folium

# %% [markdown]
# ## Using the API to pull building permit application data, as well as approved building permit data, that is related to commercial building.

# %% [markdown]
# #### First bring in the shapefiles for use later:

# %%
#council_districts = gpd.read_file('../data/CD/CD.shp')

# %%
business_improvement_districts = gpd.read_file('../data/BID/BID.shp')

# %%
#check for EPSG 4326
print(business_improvement_districts.crs)
# Out:
# epsg:4326

# %%
type(business_improvement_districts)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ## Now, permit application data:
# https://data.nashville.gov/Licenses-Permits/Building-Permit-Applications/kqff-rxj8

# %%
endpoint = 'https://data.nashville.gov/resource/kqff-rxj8.json'

# %%
params = {'$select': 'council_district, permit_subtype_description, mapped_location, date_entered',
    '$q': 'office, commercial', 
    '$limit': 50000}
response = requests.get(endpoint, params = params)
response.status_code
# Out:
# 200

# %%
applications = response.json()
applications = pd.DataFrame(applications)
print(applications.shape)
applications.head(3)
# Out:
# (86, 4)
#   council_district             permit_subtype_description  \
# 0               33  General Office, Professional Services
# 1               18         Demolition Permit - Commercial
# 2               19  General Office, Professional Services
#
#                                      mapped_location             date_entered
# 0  {'latitude': '36.0251', 'longitude': '-86.6159...  2019-11-08T00:00:00.000
# 1  {'latitude': '36.141577', 'longitude': '-86.81...  2020-08-12T00:00:00.000
# 2  {'latitude': '36.155245', 'longitude': '-86.76...  2018-04-13T00:00:00.000

# %% [markdown]
# #### Rename headers, slice out the lat and lon as well as year:

# %%
applications.columns = ['Council District', 'Permit Description', 'Location', 'Year']

# %%
applications.dropna()
# Out:
#    Council District                     Permit Description  \
# 0                33  General Office, Professional Services
# 1                18         Demolition Permit - Commercial
# 2                19  General Office, Professional Services
# 3                21          Leasing / Sales Office, Other
# 4                14  Medical Office, Professional Services
# ..              ...                                    ...
# 81                3  General Office, Professional Services
# 82               11  General Office, Professional Services
# 83               14  General Office, Professional Services
# 84               19   General Office, Civic Administration
# 85               19  General Office, Professional Services
#
#                                              Location                     Year
# 0   {'latitude': '36.0251', 'longitude': '-86.6159...  2019-11-08T00:00:00.000
# 1   {'latitude': '36.141577', 'longitude': '-86.81...  2020-08-12T00:00:00.000
# 2   {'latitude': '36.155245', 'longitude': '-86.76...  2018-04-13T00:00:00.000
# 3   {'latitude': '36.150553', 'longitude': '-86.80...  2019-09-06T00:00:00.000
# 4   {'latitude': '36.173402', 'longitude': '-86.60...  2019-06-04T00:00:00.000
# ..                                                ...                      ...
# 81  {'latitude': '36.247745', 'longitude': '-86.75...  2019-01-23T00:00:00.000
# 82  {'latitude': '36.226417', 'longitude': '-86.62...  2019-02-21T00:00:00.000
# 83  {'latitude': '36.186123', 'longitude': '-86.62...  2020-12-29T00:00:00.000
# 84  {'latitude': '36.164679', 'longitude': '-86.77...  2020-12-18T00:00:00.000
# 85  {'latitude': '36.149511', 'longitude': '-86.80...  2020-11-12T00:00:00.000
#
# [86 rows x 4 columns]

# %%
applications.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Council District    86 non-null     object
#  1   Permit Description  86 non-null     object
#  2   Location            86 non-null     object
#  3   Year                86 non-null     object
# dtypes: object(4)
# memory usage: 2.8+ KB

# %%
#bring out year
applications['Year'] = applications['Year'].str.slice(0, 4)

# %%
type(applications['Location'][0])
# Out:
# dict

# %%
applications['Location'].head().apply(lambda x: x['latitude'])
# Out:
# 0      36.0251
# 1    36.141577
# 2    36.155245
# 3    36.150553
# 4    36.173402
# Name: Location, dtype: object

# %%
no_lat = []
for ind, val in applications['Location'].iteritems():
    try:
        val['latitude']
    except:
        print(ind, val)
        no_lat.append(ind)
# Out:
# 23 {'human_address': '{"address": "2275 MURFREESBORO PIKE 200", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 28 {'human_address': '{"address": "413 PORTSDALE DR", "city": "BRENTWOOD", "state": "TN", "zip": "37027"}'}
# 34 {'human_address': '{"address": "330 23RD AVE N 200", "city": "NASHVILLE", "state": "TN", "zip": "37203"}'}
# 35 {'human_address': '{"address": "3809 OCTOBER WOODS DR 102", "city": "ANTIOCH", "state": "TN", "zip": "37013"}'}
# 36 {'human_address': '{"address": "924B2 S DOUGLAS AVE", "city": "NASHVILLE", "state": "TN", "zip": "37204"}'}
# 55 {'human_address': '{"address": "28 WHITE BRIDGE PIKE 207", "city": "NASHVILLE", "state": "TN", "zip": "37205"}'}
# 61 {'human_address': '{"address": "1124C OLD HICKORY BLVD", "city": "MADISON", "state": "TN", "zip": "37115"}'}

# %%
no_lat
# Out:
# [23, 28, 34, 35, 36, 55, 61]

# %%
applications = applications.drop(no_lat)

# %%
applications['lat'] = applications['Location'].apply(lambda x: x['latitude'])

# %%
applications['lon'] = applications['Location'].apply(lambda x: x['longitude'])

# %%
applications.head(3)
# Out:
#   Council District                     Permit Description  \
# 0               33  General Office, Professional Services
# 1               18         Demolition Permit - Commercial
# 2               19  General Office, Professional Services
#
#                                             Location  Year        lat  \
# 0  {'latitude': '36.0251', 'longitude': '-86.6159...  2019    36.0251
# 1  {'latitude': '36.141577', 'longitude': '-86.81...  2020  36.141577
# 2  {'latitude': '36.155245', 'longitude': '-86.76...  2018  36.155245
#
#           lon
# 0  -86.615902
# 1  -86.813823
# 2  -86.768517

# %%
applications = applications.drop(columns = ['Location'])

# %% [markdown]
# #### Create a GeoDataFrame:

# %%
applications['geometry'] = applications.apply(lambda x: Point((float(x.lon), 
                                                         float(x.lat))), axis=1)
applications.head(3)
# Out:
#   Council District                     Permit Description  Year        lat  \
# 0               33  General Office, Professional Services  2019    36.0251
# 1               18         Demolition Permit - Commercial  2020  36.141577
# 2               19  General Office, Professional Services  2018  36.155245
#
#           lon                            geometry
# 0  -86.615902  POINT (-86.61590200000001 36.0251)
# 1  -86.813823        POINT (-86.813823 36.141577)
# 2  -86.768517        POINT (-86.768517 36.155245)

# %%
applications_geo = gpd.GeoDataFrame(applications,
                                   crs = business_improvement_districts.crs,
                                   geometry = applications['geometry'])

# %%
type(applications_geo)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ##### Limit to CBID areas:

# %%
applications_geo_cbid = gpd.sjoin(business_improvement_districts, applications_geo, how = 'inner')

# %% [markdown]
# ## Now approved permit data:
# https://data.nashville.gov/Licenses-Permits/Building-Permits-Issued/3h5w-q8b7

# %%
endpoint = 'https://data.nashville.gov/resource/3h5w-q8b7.json'

# %%
params = {'$select': 'council_dist, permit_subtype_description, mapped_location, date_issued',
    '$q': 'office, commercial', 
    '$limit': 50000}
response = requests.get(endpoint, params = params)
response.status_code
# Out:
# 200

# %%
issued = response.json()
issued = pd.DataFrame(issued)
print(issued.shape)
issued.head(3)
# Out:
# (1881, 4)
#   council_dist             permit_subtype_description  \
# 0           26  General Office, Professional Services
# 1           25  General Office, Professional Services
# 2            6  General Office, Professional Services
#
#                                      mapped_location              date_issued
# 0  {'latitude': '36.088419', 'longitude': '-86.74...  2019-09-18T00:00:00.000
# 1  {'human_address': '{"address": "3796 BEDFORD A...  2019-03-21T00:00:00.000
# 2  {'latitude': '36.173405', 'longitude': '-86.76...  2019-06-25T00:00:00.000

# %%
issued.columns = ['Council District', 'Permit Description', 'Location', 'Year']

# %%
issued.dropna()
# Out:
#      Council District                     Permit Description  \
# 0                  26  General Office, Professional Services
# 1                  25  General Office, Professional Services
# 2                   6  General Office, Professional Services
# 3                  21  Medical Office, Professional Services
# 4                   4   General Office, Civic Administration
# ...               ...                                    ...
# 1876               15  General Office, Professional Services
# 1877               17  General Office, Professional Services
# 1878               19  General Office, Professional Services
# 1879               15  General Office, Professional Services
# 1880               19  General Office, Professional Services
#
#                                                Location  \
# 0     {'latitude': '36.088419', 'longitude': '-86.74...
# 1     {'human_address': '{"address": "3796 BEDFORD A...
# 2     {'latitude': '36.173405', 'longitude': '-86.76...
# 3     {'latitude': '36.154683', 'longitude': '-86.80...
# 4     {'latitude': '36.040754', 'longitude': '-86.76...
# ...                                                 ...
# 1876  {'latitude': '36.146759', 'longitude': '-86.69...
# 1877  {'latitude': '36.11911', 'longitude': '-86.755...
# 1878  {'latitude': '36.150413', 'longitude': '-86.79...
# 1879  {'latitude': '36.148792', 'longitude': '-86.68...
# 1880  {'latitude': '36.162705', 'longitude': '-86.77...
#
#                          Year
# 0     2019-09-18T00:00:00.000
# 1     2019-03-21T00:00:00.000
# 2     2019-06-25T00:00:00.000
# 3     2019-06-03T00:00:00.000
# 4     2020-07-06T00:00:00.000
# ...                       ...
# 1876  2021-02-11T00:00:00.000
# 1877  2019-09-27T00:00:00.000
# 1878  2021-02-12T00:00:00.000
# 1879  2021-02-12T00:00:00.000
# 1880  2021-02-12T00:00:00.000
#
# [1872 rows x 4 columns]

# %%
issued.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1881 entries, 0 to 1880
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Council District    1872 non-null   object
#  1   Permit Description  1881 non-null   object
#  2   Location            1881 non-null   object
#  3   Year                1881 non-null   object
# dtypes: object(4)
# memory usage: 58.9+ KB

# %%
#bring out year
issued['Year'] = issued['Year'].str.slice(0, 4)

# %%
type(issued['Location'][0])
# Out:
# dict

# %%
no_lat = []
for ind, val in issued['Location'].iteritems():
    try:
        val['latitude']
    except:
        #print(ind, val)
        no_lat.append(ind)

# %%
issued = issued.drop(no_lat)

# %%
issued['lat'] = issued['Location'].apply(lambda x: x['latitude'])
issued['lon'] = issued['Location'].apply(lambda x: x['longitude'])

# %%
issued = issued.drop(columns = ['Location'])

# %% [markdown]
# #### Make a GeoDataFrame for Points

# %%
issued['geometry'] = issued.apply(lambda x: Point((float(x.lon), 
                                                         float(x.lat))), axis=1)
issued.head(3)
# Out:
#   Council District                     Permit Description  Year        lat  \
# 0               26  General Office, Professional Services  2019  36.088419
# 2                6  General Office, Professional Services  2019  36.173405
# 3               21  Medical Office, Professional Services  2019  36.154683
#
#           lon                              geometry
# 0  -86.748409          POINT (-86.748409 36.088419)
# 2  -86.763282          POINT (-86.763282 36.173405)
# 3  -86.804336  POINT (-86.80433600000001 36.154683)

# %%
issued_geo = gpd.GeoDataFrame(issued,
                                   crs = business_improvement_districts.crs,
                                   geometry = issued['geometry'])

# %%
type(issued_geo)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ##### Limit to CBID areas:

# %%
issued_geo_cbid = gpd.sjoin(business_improvement_districts, issued_geo, how = 'inner')

# %%
issued_geo_cbid.head()
# Out:
#        area  date_est_d    time_est_d   id  date_modif    time_modif  \
# 0  0.598798  1998-02-06  00:00:00.000  0.0  2017-03-08  00:00:00.000
# 0  0.598798  1998-02-06  00:00:00.000  0.0  2017-03-08  00:00:00.000
# 0  0.598798  1998-02-06  00:00:00.000  0.0  2017-03-08  00:00:00.000
# 0  0.598798  1998-02-06  00:00:00.000  0.0  2017-03-08  00:00:00.000
# 0  0.598798  1998-02-06  00:00:00.000  0.0  2017-03-08  00:00:00.000
#
#                                     name  objectid   ordinance    shape_star  \
# 0  Central Business Improvement District       2.0  BL2017-580  1.669347e+07
# 0  Central Business Improvement District       2.0  BL2017-580  1.669347e+07
# 0  Central Business Improvement District       2.0  BL2017-580  1.669347e+07
# 0  Central Business Improvement District       2.0  BL2017-580  1.669347e+07
# 0  Central Business Improvement District       2.0  BL2017-580  1.669347e+07
#
#      shape_stle                                           geometry  \
# 0  20206.601116  POLYGON ((-86.78557 36.15742, -86.78417 36.158...
# 0  20206.601116  POLYGON ((-86.78557 36.15742, -86.78417 36.158...
# 0  20206.601116  POLYGON ((-86.78557 36.15742, -86.78417 36.158...
# 0  20206.601116  POLYGON ((-86.78557 36.15742, -86.78417 36.158...
# 0  20206.601116  POLYGON ((-86.78557 36.15742, -86.78417 36.158...
#
#    index_right Council District                     Permit Description  Year  \
# 0         1274               19          Leasing / Sales Office, Other  2019
# 0          192               19                          Hotel / Motel  2019
# 0         1554               19                          Hotel / Motel  2019
# 0         1488               19          Leasing / Sales Office, Other  2019
# 0          450               19  General Office, Professional Services  2019
#
#          lat         lon
# 0  36.155686  -86.775281
# 0  36.156512  -86.771695
# 0  36.156542  -86.775863
# 0  36.158069  -86.780135
# 0  36.158821  -86.775739

# %% [markdown]
# ## Bring this all into Folium:

# %%
#basemap (used state cap. for the lat/long)
base = folium.Map(location = [36.159996, -86.778281], zoom_start = 14.2, control_scale = True)

            
#create cluster with applications
marker_cluster = MarkerCluster(name = 'Permit Applications').add_to(base)

for row_index, row_values in applications_geo_cbid.iterrows():
        loc = row_values['lat'], row_values['lon']
        pop = str(row_values['Permit Description'])
        icon = folium.Icon(color = 'red', prefix = 'fa')
        marker = folium.Marker(location = loc,
                              popup = pop,
                              icon = icon)
        marker.add_to(marker_cluster)
        
#create cluster with issued
marker_cluster = MarkerCluster(name = 'Issued Permits').add_to(base)

for row_index, row_values in issued_geo_cbid.iterrows():
        loc = row_values['lat'], row_values['lon']
        pop = str(row_values['Permit Description'])
        icon = folium.Icon(color = 'green', prefix = 'fa')
        marker = folium.Marker(location = loc,
                              popup = pop,
                              icon = icon)
        marker.add_to(marker_cluster)
        
#add business improvement district polygons
folium.GeoJson(business_improvement_districts, name = 'Business Improvement Districts').add_to(base)

#enable layer control
folium.LayerControl().add_to(base)

# %%
base
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e24b8047909446a883e8c8e8a9e71f25%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e24b8047909446a883e8c8e8a9e71f25%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A ...

# %% [markdown]
# ### Takeaways from folium map:
#
# ###### Note that red markers indicate permit applications, where green indicate issued permits.
